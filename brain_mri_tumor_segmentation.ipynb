# %% [markdown]
# **Import**

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm
from skimage.filters import threshold_otsu, threshold_sauvola
from skimage.morphology import closing, disk, remove_small_objects
from sklearn.metrics import jaccard_score

# %%
# --- CONFIGURATION ---
IMAGE_DIR = "images/"
MASK_DIR = "masks/"

# %% [markdown]
# **Metrics**

# %%
def dice_score(y_true, y_pred):
    y_true = y_true.flatten()
    y_pred = y_pred.flatten()
    
    intersection = np.sum(y_true * y_pred)
    return (2. * intersection) / (np.sum(y_true) + np.sum(y_pred) + 1e-8)

# %%
def jaccard_index(y_true, y_pred):
    return jaccard_score(y_true.flatten(), y_pred.flatten())

# %% [markdown]
# **Preprocessing and Postprocessing**

# %%
def preprocess(img):

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # contrast normalization
    gray = cv2.normalize(gray, None, 0, 255, cv2.NORM_MINMAX)

    # CLAHE improves MRI contrast
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    gray = clahe.apply(gray)

    gray = cv2.GaussianBlur(gray, (5,5), 0)

    return gray

# %%
def extract_brain_region(img):

    t = threshold_otsu(img)
    mask = img > t

    mask = closing(mask, disk(5))
    mask = remove_small_objects(mask, max_size=5000)

    # keep largest connected component only
    labels = cv2.connectedComponents(mask.astype(np.uint8))[1]
    largest = labels == np.argmax(np.bincount(labels.flat)[1:]) + 1

    return largest.astype(np.uint8)

# %%
def keep_best_component(mask, min_size=50, max_size=5000):

    num, labels = cv2.connectedComponents(mask.astype(np.uint8))

    best = np.zeros_like(mask)

    for i in range(1, num):

        comp = (labels == i)
        area = np.sum(comp)

        if min_size < area < max_size:
            best = best | comp

    return best.astype(np.uint8)

# %%
def otsu_segmentation(img):

    brain = extract_brain_region(img)

    roi = img * brain

    # only use high-intensity pixels
    p90 = np.percentile(roi[brain==1], 90)

    tumor = roi > p90

    tumor = closing(tumor, disk(2))
    tumor = keep_best_component(tumor)

    return tumor

# %%
def sauvola_segmentation(img):

    brain = extract_brain_region(img)

    thresh = threshold_sauvola(img, window_size=25, k=0.15)

    local = img > thresh

    # add brightness filter
    bright = img > np.percentile(img[brain==1], 85)

    tumor = local & bright & brain

    tumor = closing(tumor, disk(2))
    tumor = keep_best_component(tumor)

    return tumor

# %%
image_files = sorted(os.listdir(IMAGE_DIR))
mask_files  = sorted(os.listdir(MASK_DIR))

pairs = list(zip(image_files, mask_files))
len(pairs)
# Out:
# 3064

# %%
dice_otsu = []
dice_sauvola = []

jac_otsu = []
jac_sauvola = []

# %% [markdown]
# **Main loop**

# %%
for img_name, mask_name in tqdm(pairs):

    img_path  = os.path.join(IMAGE_DIR, img_name)
    mask_path = os.path.join(MASK_DIR, mask_name)

    img  = cv2.imread(img_path)
    mask = cv2.imread(mask_path, 0)

    if img is None or mask is None:
        continue

    img_p = preprocess(img)

    mask = (mask > 127).astype(np.uint8)

    # skip slices without tumor (important for fair Dice)
    if np.sum(mask) == 0:
        continue

    otsu_mask = otsu_segmentation(img_p)
    sau_mask  = sauvola_segmentation(img_p)

    dice_otsu.append(dice_score(mask, otsu_mask))
    dice_sauvola.append(dice_score(mask, sau_mask))

    jac_otsu.append(jaccard_index(mask, otsu_mask))
    jac_sauvola.append(jaccard_index(mask, sau_mask))
# Out:
#   0%|          | 0/3064 [00:00<?, ?it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#   0%|          | 1/3064 [00:00<16:01,  3.18it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#   0%|          | 2/3064 [00:00<13:51,  3.68it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#   0%|          | 3/3064 [00:00<14:15,  3.58it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#   0%|          | 4/3064 [00:01<14:25,  3.54it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#   0%|          | 5/3064 [00:01<13:33,  3.76it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#   0%|          | 6/3064 [00:01<12:48,  3.98it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#   0%|          |
/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#   3%|▎         | 82/3064 [00:20<10:16,  4.84it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#   3%|▎         | 83/3064 [00:20<10:07,  4.91it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#   3%|▎         | 84/3064 [00:20<10:25,  4.76it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#   3%|▎         | 85/3064 [00:21<10:24,  4.77it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#   3%|▎         | 86/3064 [00:21<10:03,  4.94it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#   3%|▎         | 87/3064 [00:21<10:26,  4.75it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# ...
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3035/3064 [16:52<00:14,  2.02it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3036/3064 [16:52<00:13,  2.02it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3037/3064 [16:53<00:12,  2.10it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3038/3064 [16:53<00:11,  2.24it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3039/3064 [16:53<00:11,  2.14it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3040/3064 [16:54<00:10,  2.19it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3041/3064 [16:54<00:10,  2.21it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3042/3064 [16:55<00:10,  2.08it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3043/3064 [16:55<00:09,  2.21it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3044/3064 [16:56<00:09,  2.20it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3045/3064 [16:56<00:08,  2.22it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3046/3064 [16:57<00:07,  2.34it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3047/3064 [16:57<00:07,  2.38it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
#  99%|█████████▉| 3048/3064 [16:57<00:06,  2.39it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3049/3064 [16:58<00:06,  2.40it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3050/3064 [16:58<00:05,  2.57it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3051/3064 [16:58<00:05,  2.48it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3052/3064 [16:59<00:04,  2.53it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3053/3064 [16:59<00:04,  2.59it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3054/3064 [17:00<00:04,  2.42it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3055/3064 [17:00<00:03,  2.35it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3056/3064 [17:01<00:03,  2.46it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3057/3064 [17:01<00:02,  2.59it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3058/3064 [17:01<00:02,  2.51it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3059/3064 [17:02<00:01,  2.54it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3060/3064 [17:02<00:01,  2.48it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3061/3064 [17:02<00:01,  2.56it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3062/3064 [17:03<00:00,  2.71it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|█████████▉| 3063/3064 [17:03<00:00,  2.68it/s]C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
# 100%|██████████| 3064/3064 [17:04<00:00,  2.99it/s]

# %% [markdown]
# **Results**

# %%
print("===== RESULTS =====")

print("\nOtsu Thresholding")
print("Dice     :", np.mean(dice_otsu))
print("Jaccard  :", np.mean(jac_otsu))

print("\nSauvola Thresholding")
print("Dice     :", np.mean(dice_sauvola))
print("Jaccard  :", np.mean(jac_sauvola))
# Out:
# ===== RESULTS =====
#
# Otsu Thresholding
# Dice     : 0.08942317302730271
# Jaccard  : 0.05062177387783899
#
# Sauvola Thresholding
# Dice     : 0.13646872808971086
# Jaccard  : 0.08018595248556093

# %%
def show_sample(i):

    img = cv2.imread(os.path.join(IMAGE_DIR, image_files[i]))
    mask = cv2.imread(os.path.join(MASK_DIR, mask_files[i]), 0)

    img_p = preprocess(img)

    otsu_m = otsu_segmentation(img_p)
    sau_m  = sauvola_segmentation(img_p)

    plt.figure(figsize=(12,4))

    plt.subplot(1,4,1)
    plt.imshow(img_p, cmap='gray')
    plt.title("MRI")

    plt.subplot(1,4,2)
    plt.imshow(mask, cmap='gray')
    plt.title("Ground Truth")

    plt.subplot(1,4,3)
    plt.imshow(otsu_m, cmap='gray')
    plt.title("Otsu")

    plt.subplot(1,4,4)
    plt.imshow(sau_m, cmap='gray')
    plt.title("Sauvola")

    plt.show()

# %%
show_sample(10)
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_19244\2424744834.py:7: FutureWarning: Parameter `min_size` is deprecated since version 0.26.0 and will be removed in 2.0.0 (or later). To avoid this warning, please use the parameter `max_size` instead. For more details, see the documentation of `remove_small_objects`. Note that the new threshold removes objects smaller than **or equal to** its value, while the previous parameter only removed smaller ones.
#   mask = remove_small_objects(mask, 5000)
